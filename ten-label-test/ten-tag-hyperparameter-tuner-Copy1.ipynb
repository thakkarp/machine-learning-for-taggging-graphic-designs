# %%
import sagemaker
from sagemaker import get_execution_role
from sagemaker.amazon.amazon_estimator import image_uris

role = get_execution_role()
sess = sagemaker.Session()

# %%
bucket = 'sagemaker-multi-label-test'
prefix = 'ic-multilabel'

s3train = 's3://{}/{}/train/'.format(bucket, prefix)
s3validation = 's3://{}/{}/validation/'.format(bucket, prefix)

# %%
train_data = sagemaker.inputs.TrainingInput(
    s3train, 
    distribution='FullyReplicated', 
    content_type='application/x-recordio', 
    s3_data_type='S3Prefix'
)

validation_data = sagemaker.inputs.TrainingInput(
    s3validation, 
    distribution='FullyReplicated', 
    content_type='application/x-recordio', 
    s3_data_type='S3Prefix'
)

data_channels = {'train': train_data, 'validation': validation_data}

s3_output_location = 's3://{}/{}/output'.format(bucket, prefix)

# %%
from sagemaker.image_uris import retrieve, config_for_framework
training_image = retrieve('image-classification', sess.boto_region_name, )
print (training_image)
# Out:
# 685385470294.dkr.ecr.eu-west-1.amazonaws.com/image-classification:1

# %%
multilabel_ic = sagemaker.estimator.Estimator(training_image,
                                             role, 
                                             instance_count=1, 
                                             instance_type='ml.p3.2xlarge',
                                             output_path=s3_output_location,
                                             sagemaker_session=sess)

# %%
multilabel_ic.set_hyperparameters(num_layers=18,
                                image_shape = '3,224,224',
                                num_classes=10,
                                epochs=50,
                                num_training_samples=3457,
                                use_weighted_loss=1,
                                precision_dtype='float32',
                                augmentation_type = 'crop',
                                multi_label=1,
                                top_k=2)

# %%
from sagemaker.tuner import IntegerParameter, CategoricalParameter, ContinuousParameter, HyperparameterTuner
from time import gmtime, strftime

tuning_job_name = "imageclassif-job-{}".format(strftime("%d-%H-%M-%S", gmtime()))

hyperparameter_ranges = {'learning_rate': ContinuousParameter(0.00044593590936931976, 0.05, 'Logarithmic'),
                         'mini_batch_size': IntegerParameter(90, 200),
                         'optimizer': CategoricalParameter(['adam', 'nag'])}

objective_metric_name = 'validation:accuracy'

tuner = HyperparameterTuner(multilabel_ic,
                            objective_metric_name,
                            hyperparameter_ranges,
                            objective_type='Maximize',
                            max_jobs=10,
                            max_parallel_jobs=1)

# %%
tuner.fit(data_channels, job_name=tuning_job_name, include_cls_metadata=False)
tuner.wait()
# Out:
# ....................................................................................................................................................................................................................................................................................................

# %%
best_job = tuner.best_estimator()
# Out:
# 2021-03-04 01:16:47 Starting - Preparing the instances for training
# 2021-03-04 01:16:47 Downloading - Downloading input data
# 2021-03-04 01:16:47 Training - Training image download completed. Training in progress.
# 2021-03-04 01:16:47 Uploading - Uploading generated training model
# 2021-03-04 01:16:47 Completed - Training job completed

# %%
ic_classifier = best_job.deploy(initial_instance_count = 1, instance_type = 'ml.m4.xlarge')
# Out:
# -----------------!

# %%
import boto3
import botocore
import mxnet as mx
from PIL import Image
import numpy as np

lst = open('val.lst')
s3 = boto3.resource('s3')

bucket = 'pixelscrapper-user-content'
image_dir = 'test-images/'
img_labels = []
img_paths = []

i = 0
for line in lst:
    if i <= 30:
        line = line.split()
        s3_img_path = line[len(line) - 1][1:]
        local_img_path = s3_img_path.split('/')
        local_img_path = local_img_path[len(local_img_path) - 1]
        img_paths.append(image_dir + local_img_path)
        img_labels.append([float(i) for i in line[1:len(line)-1]])
        s3.Bucket(bucket).download_file(s3_img_path, image_dir + local_img_path)
        
        
        img = Image.open(image_dir + local_img_path)
        img = img.convert("RGB")   
        img_array = np.array(img.resize((224, 224)))
        Image.fromarray(img_array).save(image_dir + local_img_path)
        
        
        i = i+1
    else:
        break

# %%
import json
import boto3
 
endpoint = 'imageclassif-job-04-00-06-49-008-fa1272-2021-03-04-01-59-50-199' 
runtime = boto3.Session().client('sagemaker-runtime')
tags = ['flower','leaf','star','heart','christmas','template','word art','tag','vintage','illustration']
i = 0
for path in img_paths:
    with open(path, 'rb') as f:
        payload = f.read()
    response = runtime.invoke_endpoint(EndpointName=endpoint, ContentType='application/x-image', Body=payload)
    result = json.loads(response['Body'].read().decode())
    print('-------------------------------------')
    print('image:  ' + path)
    j = 0
    print()
    print('actual' + '\t' + 'tag' + '\t' + '\t' + 'response')
    s = 0
    for tag in img_labels[i]:
        s = s+result[j]
        print(str(tag) + '\t' + tags[j] + '\t' + '\t' + str(result[j]))
        j = j+1
    i = i+1
    print(s)
# Out:
# -------------------------------------
# image:  test-images/my-bujo-day-blue-12-graphic-tag-number-planner-element-embellishment-green-white.png
#
# actual	tag		response
# 0.0	flower		0.002540196292102337
# 0.0	leaf		0.9431027770042419
# 0.0	star		0.00028306094463914633
# 0.0	heart		0.003589375875890255
# 0.0	christmas		0.0006178766489028931
# 0.0	template		1.4928184100426733e-05
# 0.0	word art		0.000949955836404115
# 1.0	tag		0.0001413622812833637
# 0.0	vintage		0.1128220334649086
# 0.0	illustration		0.0015701208030804992
# 1.0656316873355536
# -------------------------------------
# image:  test-images/seriously-floral-tag07i-graphic-tag-element-vintage-red-yellow-green-pink.png
#
# actual	tag		response
# 0.0	flower		0.03150792047381401
# 0.0	leaf		0.027877531945705414
# 0.0	star		0.0003635817556641996
# 0.0	heart		9.193750156555325e-05
# 0.0	christmas		0.052676696330308914
# 0.0	template		4.864662332693115e-05
# 0.0	word art		0.0032706407364457846
# 1.0	tag		0.007840005680918694
# 1.0	vintage		0.3538884222507477
# 0.0	illustration		0.2608150839805603
# 0.7383804672790575
# -------------------------------------
# image:  test-images/summer-splash-illustrations-1-popsicle-graphic-element-illustration-beach-pool-orange-yellow-green.png
#
# actual	tag		response
# 0.0	flower		0.006345652975142002
# 0.0	leaf		0.08750604093074799
# 0.0	star		0.08934806287288666
# 0.0	heart		0.0018799146637320518
# 0.0	christmas		0.0010857773013412952
# 0.0	template		0.011938471347093582
# 0.0	word art		0.02089044637978077
# 0.0	tag		0.0519748292863369
# 0.0	vintage		0.00040174886817112565
# 1.0	illustration		0.0017742789350450039
# 0.2731452235602774
# -------------------------------------
# image:  test-images/lil-monster-orange-star-stamp-asset-shape-cutout-embellishment.png
#
# actual	tag		response
# 0.0	flower		0.8377812504768372
# 0.0	leaf		0.010187664069235325
# 1.0	star		6.528092490043491e-05
# 0.0	heart		2.5665956400189316e-06
# 0.0	christmas		0.00015769482706673443
# 0.0	template		0.0009215614409185946
# 0.0	word art		0.039410512894392014
# 0.0	tag		0.01441999338567257
# 0.0	vintage		0.14754050970077515
# 0.0	illustration		0.004128183238208294
# 1.0546152175536463
# -------------------------------------
# image:  test-images/flower-stamp-03-graphic-flowers-template-element-black_0.png
#
# actual	tag		response
# 0.0	flower		1.0220210810985009e-07
# 0.0	leaf		2.9402617656160146e-06
# 0.0	star		7.669797241760534e-08
# 0.0	heart		2.9231005100882612e-05
# 0.0	christmas		0.13234521448612213
# 1.0	template		0.9996612071990967
# 0.0	word art		2.1036472389823757e-05
# 0.0	tag		8.763787263887934e-06
# 0.0	vintage		0.9599231481552124
# 0.0	illustration		0.9999802112579346
# 3.0919719315249665
# -------------------------------------
# image:  test-images/butterfly-template-063-graphic-element-embellishment-paper-vintage-ephemera-insect-wings-white-gray.png
#
# actual	tag		response
# 0.0	flower		0.01563289575278759
# 0.0	leaf		0.818985641002655
# 0.0	star		1.212420670526626e-06
# 0.0	heart		0.00035885939723812044
# 0.0	christmas		5.700558631360764e-06
# 1.0	template		0.9997321963310242
# 0.0	word art		3.603671939345077e-05
# 0.0	tag		8.311298734042794e-05
# 1.0	vintage		0.47744378447532654
# 0.0	illustration		0.15777310729026794
# 2.470052546935335
# -------------------------------------
# image:  test-images/retro-holly-jolly-flair-2-graphic-santa-christmas-december-2018-blog-train-button-red-light-green.png
#
# actual	tag		response
# 0.0	flower		0.07499845325946808
# 0.0	leaf		0.0014560151612386107
# 0.0	star		4.76168224849971e-06
# 0.0	heart		0.0057601723819971085
# 1.0	christmas		4.6409517381107435e-05
# 0.0	template		0.011747661978006363
# 0.0	word art		0.006539875641465187
# 0.0	tag		0.004152781330049038
# 0.0	vintage		0.9407098293304443
# 0.0	illustration		0.00418106047436595
# 1.0495970207566643
# -------------------------------------
# image:  test-images/retro-holly-jolly-paper-16-graphic-pattern-christmas-december-2018-blog-train-ornaments-green-olive.jpg
#
# actual	tag		response
# 0.0	flower		0.013808708637952805
# 0.0	leaf		0.2759180963039398
# 0.0	star		0.06581126898527145
# 0.0	heart		0.0003756952937692404
# 1.0	christmas		0.9963513612747192
# 0.0	template		0.0011777556501328945
# 0.0	word art		0.0002638043952174485
# 0.0	tag		0.00013233680510893464
# 0.0	vintage		0.01234174333512783
# 0.0	illustration		0.0003816300886683166
# 1.366562400769908
# -------------------------------------
# image:  test-images/stitched-tag-love-this-moment-with-shadows-graphic-element-stitches-tag-word-art-white-cream-black.png
#
# actual	tag		response
# 0.0	flower		0.328203946352005
# 0.0	leaf		0.00040912360418587923
# 0.0	star		0.9216777086257935
# 0.0	heart		1.077395495485689e-06
# 0.0	christmas		3.1150473205343587e-06
# 0.0	template		6.263345858315006e-05
# 1.0	word art		0.0005627828650176525
# 1.0	tag		0.008944224566221237
# 0.0	vintage		0.00017117202514782548
# 0.0	illustration		2.93379770255342e-07
# 1.2600360773195405
# -------------------------------------
# image:  test-images/furry-cuddles-moment-captured-word-art-graphic-element-embellishment-label-rectangle-white-black.png
#
# actual	tag		response
# 0.0	flower		4.0070190152619034e-05
# 0.0	leaf		0.00013347892672754824
# 0.0	star		7.926334365038201e-05
# 0.0	heart		0.005059208255261183
# 0.0	christmas		0.00047319280565716326
# 0.0	template		0.0003741785476449877
# 1.0	word art		0.9296969175338745
# 0.0	tag		0.9383265972137451
# 0.0	vintage		9.030386536323931e-06
# 0.0	illustration		2.3171207431005314e-05
# 1.8742151084106808
# -------------------------------------
# image:  test-images/travel-log-word-art-did-graphic-black.png
#
# actual	tag		response
# 0.0	flower		0.032273069024086
# 0.0	leaf		0.10983645170927048
# 0.0	star		0.0013965046964585781
# 0.0	heart		0.0003014075628016144
# 0.0	christmas		0.0005621545715257525
# 0.0	template		0.9997449517250061
# 1.0	word art		0.2534768283367157
# 0.0	tag		0.006517005153000355
# 0.0	vintage		0.010324224829673767
# 0.0	illustration		0.8539791107177734
# 2.268411708326312
# -------------------------------------
# image:  test-images/cast-a-spell-swirls-and-leaf-brush-template-stamp-illustration-autumn-fall-pumpkin.png
#
# actual	tag		response
# 0.0	flower		0.979469895362854
# 1.0	leaf		3.2199670386034995e-05
# 0.0	star		1.4767543689231388e-05
# 0.0	heart		0.0034951497800648212
# 0.0	christmas		2.685358231246937e-05
# 1.0	template		0.9985645413398743
# 0.0	word art		4.558564796752762e-06
# 0.0	tag		3.230769652873278e-05
# 0.0	vintage		0.0012057997519150376
# 1.0	illustration		0.0035431766882538795
# 1.9863892499806752
# -------------------------------------
# image:  test-images/winter-day-us-word-art-graphic-element-embellishment-snippet-tag-strip-rectangle-saying-printing.png
#
# actual	tag		response
# 0.0	flower		8.1382804637542e-06
# 0.0	leaf		0.06506313383579254
# 0.0	star		0.00012041804438922554
# 0.0	heart		2.4351997126359493e-05
# 0.0	christmas		0.005108523182570934
# 0.0	template		0.05732680857181549
# 1.0	word art		0.9888705015182495
# 1.0	tag		0.19725970923900604
# 0.0	vintage		3.2755401662143413e-06
# 0.0	illustration		0.011512326076626778
# 1.3252971862862069
# -------------------------------------
# image:  test-images/desert-spring-elements-tag-go-graphic-circle-element-green-white.png
#
# actual	tag		response
# 0.0	flower		0.009779746644198895
# 0.0	leaf		0.2773020267486572
# 0.0	star		0.014367715455591679
# 0.0	heart		0.0006230221479199827
# 0.0	christmas		0.019702710211277008
# 0.0	template		0.0010048442054539919
# 0.0	word art		0.10114117711782455
# 1.0	tag		0.8430225253105164
# 0.0	vintage		0.0006864949245937169
# 0.0	illustration		0.00535134132951498
# 1.2729816040955484
# -------------------------------------
# image:  test-images/fabric-flower-05-graphic-bud-element-gold-green-blue.png
#
# actual	tag		response
# 1.0	flower		2.650583155627828e-05
# 0.0	leaf		0.9976377487182617
# 0.0	star		0.002154415240511298
# 0.0	heart		0.0069106644950807095
# 0.0	christmas		0.01972064934670925
# 0.0	template		2.028089511441067e-05
# 0.0	word art		0.00018913311942014843
# 0.0	tag		0.00036976742558181286
# 0.0	vintage		0.0006915833801031113
# 0.0	illustration		0.5326184034347534
# 1.5603391518870922
# -------------------------------------
# image:  test-images/toolboxstamps-handwriting-10-asset-word-art-handwriting-writing-script-calligraphy-words-stamps.png
#
# actual	tag		response
# 0.0	flower		2.2247901142691262e-05
# 0.0	leaf		0.0018705639522522688
# 0.0	star		0.04332573711872101
# 0.0	heart		0.010039418004453182
# 0.0	christmas		0.005634423345327377
# 0.0	template		0.9020254015922546
# 1.0	word art		0.030872898176312447
# 0.0	tag		0.002844582311809063
# 1.0	vintage		0.18596485257148743
# 0.0	illustration		0.0091543635353446
# 1.1917544885091047
# -------------------------------------
# image:  test-images/christmas-tradition-gift-graphic-element-embellishment-red-green.png
#
# actual	tag		response
# 0.0	flower		0.041059400886297226
# 0.0	leaf		0.13445572555065155
# 0.0	star		1.6870159015525132e-05
# 0.0	heart		2.44634748014505e-07
# 1.0	christmas		0.10348617285490036
# 0.0	template		0.058153584599494934
# 0.0	word art		0.02127666398882866
# 0.0	tag		0.0014853432076051831
# 0.0	vintage		0.0005855549825355411
# 0.0	illustration		0.1624184399843216
# 0.5229380008483986
# -------------------------------------
# image:  test-images/byb-tags-3-tag-5b-graphic-element-circle-stripes-peach-green-white.png
#
# actual	tag		response
# 0.0	flower		0.0009221946820616722
# 0.0	leaf		0.0006275040796026587
# 0.0	star		2.6583849830785766e-05
# 0.0	heart		0.04617071896791458
# 0.0	christmas		3.195229680841294e-08
# 0.0	template		0.002310369862243533
# 0.0	word art		0.04255838692188263
# 1.0	tag		0.4585586488246918
# 0.0	vintage		0.005383883602917194
# 0.0	illustration		9.467248105465842e-07
# 0.5565592694682522
# -------------------------------------
# image:  test-images/the-good-life-march-2020-elements-glitter-heart-2-graphic-love-element-cork-white-brown.png
#
# actual	tag		response
# 0.0	flower		5.3327479690779e-05
# 0.0	leaf		3.0516574042849243e-05
# 0.0	star		0.01913408376276493
# 1.0	heart		0.4560718536376953
# 0.0	christmas		2.174217797801248e-06
# 0.0	template		0.0008975500822998583
# 0.0	word art		0.002011618809774518
# 0.0	tag		0.026959672570228577
# 0.0	vintage		0.009287350811064243
# 0.0	illustration		0.02599763683974743
# 0.5404457847851063
# -------------------------------------
# image:  test-images/sent-template-video-game-valentine-stamp-graphic-element-computer-pixels-games-teen-boy-love-quotes.png
#
# actual	tag		response
# 0.0	flower		0.006798880640417337
# 0.0	leaf		0.011343127116560936
# 0.0	star		0.6640644073486328
# 0.0	heart		0.002715318463742733
# 0.0	christmas		0.2349625825881958
# 1.0	template		0.9677658677101135
# 0.0	word art		0.9024987816810608
# 0.0	tag		0.05031498521566391
# 0.0	vintage		0.0006143121281638741
# 0.0	illustration		0.02721204049885273
# 2.8682903033914044
# -------------------------------------
# image:  test-images/slice-of-summer-leaf-doodle-3-graphic-doodles-drawings-illustrations-sketches-metal-element-green.png
#
# actual	tag		response
# 0.0	flower		0.0012399194529280066
# 1.0	leaf		0.004316798411309719
# 0.0	star		0.0015099303564056754
# 0.0	heart		0.0013116378104314208
# 0.0	christmas		0.07928137481212616
# 0.0	template		1.7467441466578748e-06
# 0.0	word art		1.0958450729958713e-05
# 0.0	tag		0.0007064153323881328
# 0.0	vintage		0.1678261011838913
# 0.0	illustration		0.2648271322250366
# 0.5210320147793936
# -------------------------------------
# image:  test-images/textured-grunge-star-08-asset-shape-cutout-stamp-embellishment-texture-distressed-white-gray.png
#
# actual	tag		response
# 0.0	flower		0.9494616985321045
# 0.0	leaf		0.010928752832114697
# 1.0	star		0.18029403686523438
# 0.0	heart		1.7402612684236374e-07
# 0.0	christmas		0.00013990009028930217
# 0.0	template		0.13809171319007874
# 0.0	word art		0.0005822711973451078
# 0.0	tag		0.0001009058760246262
# 0.0	vintage		4.652628194889985e-05
# 0.0	illustration		8.287364572368006e-09
# 1.2796459871786316
# -------------------------------------
# image:  test-images/vintage-gifts-template-graphic-illustration-element-stamp-printable-christmas-black.png
#
# actual	tag		response
# 0.0	flower		2.7433836294221692e-05
# 0.0	leaf		0.005008435342460871
# 0.0	star		5.4686603107256815e-05
# 0.0	heart		4.793920379597694e-05
# 1.0	christmas		0.004744281060993671
# 1.0	template		0.9990197420120239
# 0.0	word art		0.4500998556613922
# 0.0	tag		0.013906385749578476
# 1.0	vintage		0.003068354679271579
# 1.0	illustration		0.9827844500541687
# 2.458761564203087
# -------------------------------------
# image:  test-images/back-to-basics-everyday-label-170-graphic-tab-tag-wordart-element-details-gold-brown.png
#
# actual	tag		response
# 0.0	flower		2.6521480322116986e-05
# 0.0	leaf		2.0969488900846045e-07
# 0.0	star		0.19661186635494232
# 0.0	heart		2.1903029846725985e-05
# 0.0	christmas		8.055865237110993e-07
# 0.0	template		8.714457180758473e-06
# 0.0	word art		0.006690628826618195
# 1.0	tag		0.9995631575584412
# 0.0	vintage		0.002931057009845972
# 0.0	illustration		1.469059588998789e-05
# 1.2058695545945
# -------------------------------------
# image:  test-images/baby-it-s-cold-outside-star-graphic-winter-christmas-it-s-blue.png
#
# actual	tag		response
# 0.0	flower		0.1176963672041893
# 0.0	leaf		0.045770131051540375
# 1.0	star		0.09664532542228699
# 0.0	heart		8.513319698977284e-06
# 1.0	christmas		0.0005332191940397024
# 0.0	template		1.3996101188240573e-05
# 0.0	word art		7.390083919744939e-05
# 0.0	tag		0.0029123998247087
# 0.0	vintage		1.1570484275580384e-05
# 0.0	illustration		0.0003081147442571819
# 0.2639735381853825
# -------------------------------------
# image:  test-images/easter-elements-flower-brown-graphic-element-brad-flower-crinkled.png
#
# actual	tag		response
# 1.0	flower		7.821496183169074e-06
# 0.0	leaf		0.0011728465324267745
# 0.0	star		0.006520204246044159
# 0.0	heart		0.2169502228498459
# 0.0	christmas		0.05505530163645744
# 0.0	template		1.6214182778639952e-06
# 0.0	word art		0.0026791554410010576
# 0.0	tag		0.018943918868899345
# 0.0	vintage		1.2086203241779003e-05
# 0.0	illustration		0.02066226489841938
# 0.32200544359079686
# -------------------------------------
# image:  test-images/magic-girl-flower-graphic-element-embellishment-white.png
#
# actual	tag		response
# 1.0	flower		0.9143057465553284
# 0.0	leaf		0.00033167965011671185
# 0.0	star		0.5594764947891235
# 0.0	heart		0.0005129314376972616
# 0.0	christmas		0.0021520680747926235
# 0.0	template		0.4512368142604828
# 0.0	word art		0.07035695761442184
# 0.0	tag		0.001690165838226676
# 0.0	vintage		0.005248270463198423
# 0.0	illustration		0.0017935537034645677
# 2.007104682386853
# -------------------------------------
# image:  test-images/our-house-nov2014-blog-train-white-wood-patterened-tag-graphic-patterned-tan.png
#
# actual	tag		response
# 0.0	flower		0.5155226588249207
# 0.0	leaf		0.00022312153305392712
# 0.0	star		3.5333628147782292e-06
# 0.0	heart		0.0025117741897702217
# 0.0	christmas		0.00013566366396844387
# 0.0	template		0.0010895763989537954
# 0.0	word art		0.02093096263706684
# 1.0	tag		0.0022319802083075047
# 0.0	vintage		0.9997850060462952
# 0.0	illustration		0.0016383561305701733
# 1.5440726329957215
# -------------------------------------
# image:  test-images/quick-pages-23-e-graphic-page-premade-layout-paper-3-photos-heart-plaid-4-hole-button-flower-paint.png
#
# actual	tag		response
# 1.0	flower		9.846415923675522e-05
# 0.0	leaf		2.7261867217021063e-06
# 0.0	star		7.893590372987092e-05
# 1.0	heart		0.6433749198913574
# 0.0	christmas		0.00013263065193314105
# 0.0	template		0.0002799321955535561
# 0.0	word art		0.687716007232666
# 0.0	tag		0.221917062997818
# 0.0	vintage		0.3517542779445648
# 0.0	illustration		1.4422898857446853e-05
# 1.9053693800624387
# -------------------------------------
# image:  test-images/home-for-the-holidays-doodle-1-plate-graphic-element-embellishment-illustration-drawing-hand-drawn.png
#
# actual	tag		response
# 0.0	flower		0.004997848067432642
# 0.0	leaf		0.00028205476701259613
# 0.0	star		0.0018359097884967923
# 0.0	heart		8.093321230262518e-05
# 1.0	christmas		0.007424042094498873
# 0.0	template		0.11996914446353912
# 0.0	word art		0.10442741215229034
# 0.0	tag		0.13600264489650726
# 0.0	vintage		0.05527093634009361
# 1.0	illustration		0.02846933715045452
# 0.4587602629326284
# -------------------------------------
# image:  test-images/confidence-heart-stamp-graphic-element-black.png
#
# actual	tag		response
# 0.0	flower		8.596993694709454e-08
# 0.0	leaf		0.00035645271418616176
# 0.0	star		3.916171408491209e-05
# 1.0	heart		1.3360531738726422e-05
# 0.0	christmas		0.7488489747047424
# 0.0	template		0.9925730228424072
# 0.0	word art		0.9909971952438354
# 0.0	tag		0.00010515216126805171
# 0.0	vintage		0.0001718254789011553
# 0.0	illustration		0.8950390815734863
# 3.6281443129345874

# %%
# Out:
# -------------------------------------
# image:  test-images/my-bujo-day-blue-12-graphic-tag-number-planner-element-embellishment-green-white.png
#
# actual	response
# 0.0	0.0006384921725839376
# 0.0	0.9138441681861877
# 0.0	0.0004088479618076235
# 0.0	0.004992966074496508
# 0.0	0.0001976013445528224
# 0.0	9.837906873144675e-06
# 0.0	0.0008342984947375953
# tag	9.482325549470261e-05
# 0.0	0.29560819268226624
# 0.0	0.0011613955721259117
# -------------------------------------
# image:  test-images/seriously-floral-tag07i-graphic-tag-element-vintage-red-yellow-green-pink.png
#
# actual	response
# 0.0	0.014177469536662102
# 0.0	0.013518800027668476
# 0.0	0.0006192461005412042
# 0.0	4.2091145587619394e-05
# 0.0	0.12789542973041534
# 0.0	3.777773235924542e-05
# 0.0	0.0037602137308567762
# tag	0.01822315901517868
# vintage	0.18592289090156555
# 0.0	0.1229759007692337
# -------------------------------------
# image:  test-images/summer-splash-illustrations-1-popsicle-graphic-element-illustration-beach-pool-orange-yellow-green.png
#
# actual	response
# 0.0	0.005787249654531479
# 0.0	0.12724529206752777
# 0.0	0.06670825928449631
# 0.0	0.0013071632711216807
# 0.0	0.001287300605326891
# 0.0	0.0076547646895051
# 0.0	0.024794118478894234
# 0.0	0.04180050641298294
# 0.0	0.000565664260648191
# illustration	0.0014164289459586143
# -------------------------------------
# image:  test-images/lil-monster-orange-star-stamp-asset-shape-cutout-embellishment.png
#
# actual	response
# 0.0	0.8227702379226685
# 0.0	0.010424347594380379
# star	6.242309609660879e-05
# 0.0	3.322210886835819e-06
# 0.0	0.00012935411359649152
# 0.0	0.0008569876663386822
# 0.0	0.0475233718752861
# 0.0	0.016035232692956924
# 0.0	0.13632678985595703
# 0.0	0.004747639410197735
# -------------------------------------
# image:  test-images/flower-stamp-03-graphic-flowers-template-element-black_0.png
#
# actual	response
# 0.0	2.6627611227070247e-09
# 0.0	3.7870475466661446e-07
# 0.0	3.621581257107209e-08
# 0.0	7.157637355703628e-06
# 0.0	0.07790222018957138
# template	0.99857497215271
# 0.0	0.00013346760533750057
# 0.0	1.3236259519544546e-06
# 0.0	0.9875420928001404
# 0.0	0.9999936819076538
# -------------------------------------
# image:  test-images/butterfly-template-063-graphic-element-embellishment-paper-vintage-ephemera-insect-wings-white-gray.png
#
# actual	response
# 0.0	0.005866172723472118
# 0.0	0.6708523631095886
# 0.0	1.7592187759873923e-06
# 0.0	1.9454158973530866e-05
# 0.0	4.149745223003265e-07
# template	0.9998286962509155
# 0.0	7.212805030576419e-06
# 0.0	0.0002894863428082317
# vintage	0.1594649851322174
# 0.0	0.4257822334766388
# -------------------------------------
# image:  test-images/retro-holly-jolly-flair-2-graphic-santa-christmas-december-2018-blog-train-button-red-light-green.png
#
# actual	response
# 0.0	0.08952273428440094
# 0.0	0.001380356727167964
# 0.0	4.28334442403866e-06
# 0.0	0.005842460785061121
# christmas	3.992924030171707e-05
# 0.0	0.01389746367931366
# 0.0	0.007067421451210976
# 0.0	0.0036405983846634626
# 0.0	0.9339112043380737
# 0.0	0.004529250785708427
# -------------------------------------
# image:  test-images/retro-holly-jolly-paper-16-graphic-pattern-christmas-december-2018-blog-train-ornaments-green-olive.jpg
#
# actual	response
# 0.0	0.0038754313718527555
# 0.0	0.3852585554122925
# 0.0	0.04227433726191521
# 0.0	0.000993014662526548
# christmas	0.8843247294425964
# 0.0	0.00039547355845570564
# 0.0	0.00023568124743178487
# 0.0	0.00036185659701004624
# 0.0	0.03022070787847042
# 0.0	0.00026340928161516786
# -------------------------------------
# image:  test-images/stitched-tag-love-this-moment-with-shadows-graphic-element-stitches-tag-word-art-white-cream-black.png
#
# actual	response
# 0.0	0.6675965785980225
# 0.0	0.0003170012787450105
# 0.0	0.7594822645187378
# 0.0	1.309278559347149e-06
# 0.0	8.308035148729687e-07
# 0.0	8.651622920297086e-05
# word art	0.008935239166021347
# tag	0.007052927743643522
# 0.0	0.00014908207231201231
# 0.0	3.2741706945671467e-07
# -------------------------------------
# image:  test-images/furry-cuddles-moment-captured-word-art-graphic-element-embellishment-label-rectangle-white-black.png
#
# actual	response
# 0.0	3.676947017083876e-05
# 0.0	0.0006035816622897983
# 0.0	8.161281584762037e-05
# 0.0	0.004161374643445015
# 0.0	0.0009449016652069986
# 0.0	0.000647355685941875
# word art	0.9080969095230103
# 0.0	0.8228095769882202
# 0.0	1.5886575056356378e-05
# 0.0	5.608566789305769e-05
# -------------------------------------
# image:  test-images/travel-log-word-art-did-graphic-black.png
#
# actual	response
# 0.0	0.0036010853946208954
# 0.0	0.03837236016988754
# 0.0	0.03689262643456459
# 0.0	0.0011995724635198712
# 0.0	7.22419354133308e-05
# 0.0	0.9988548755645752
# word art	0.07890362292528152
# 0.0	0.024905413389205933
# 0.0	0.0004530699225142598
# 0.0	0.33861303329467773
# -------------------------------------
# image:  test-images/cast-a-spell-swirls-and-leaf-brush-template-stamp-illustration-autumn-fall-pumpkin.png
#
# actual	response
# 0.0	0.8587337732315063
# leaf	1.663800867390819e-05
# 0.0	6.05159584665671e-06
# 0.0	0.0016006428049877286
# 0.0	2.169948857044801e-05
# template	0.9995366334915161
# 0.0	3.7739205254183616e-06
# 0.0	5.292128480505198e-05
# 0.0	0.005170273594558239
# illustration	0.007438536733388901
# -------------------------------------
# image:  test-images/winter-day-us-word-art-graphic-element-embellishment-snippet-tag-strip-rectangle-saying-printing.png
#
# actual	response
# 0.0	4.004051788797369e-06
# 0.0	0.04700832813978195
# 0.0	8.815526234684512e-05
# 0.0	6.747973384335637e-05
# 0.0	0.004625705070793629
# 0.0	0.10443630069494247
# word art	0.9849156141281128
# tag	0.5743874907493591
# 0.0	3.232264134567231e-06
# 0.0	0.004050408024340868
# -------------------------------------
# image:  test-images/desert-spring-elements-tag-go-graphic-circle-element-green-white.png
#
# actual	response
# 0.0	0.013635950163006783
# 0.0	0.42751991748809814
# 0.0	0.006801930256187916
# 0.0	0.0003127595118712634
# 0.0	0.017040731385350227
# 0.0	0.0009370904881507158
# 0.0	0.11525275558233261
# tag	0.7354418039321899
# 0.0	0.0016267952742055058
# 0.0	0.00913269817829132
# -------------------------------------
# image:  test-images/fabric-flower-05-graphic-bud-element-gold-green-blue.png
#
# actual	response
# flower	9.513874829281121e-06
# 0.0	0.99891197681427
# 0.0	0.0017676330171525478
# 0.0	0.019515780732035637
# 0.0	0.01210940070450306
# 0.0	1.4328333236335311e-05
# 0.0	7.161986286519095e-05
# 0.0	0.00016941979993134737
# 0.0	0.0004972791648469865
# 0.0	0.4634421169757843
# -------------------------------------
# image:  test-images/toolboxstamps-handwriting-10-asset-word-art-handwriting-writing-script-calligraphy-words-stamps.png
#
# actual	response
# 0.0	5.440115273813717e-05
# 0.0	0.0016354689141735435
# 0.0	0.011098044924438
# 0.0	0.004392867907881737
# 0.0	0.004487296100705862
# 0.0	0.9867959022521973
# word art	0.07627883553504944
# 0.0	0.0034307450987398624
# vintage	0.1864074021577835
# 0.0	0.014913689345121384
# -------------------------------------
# image:  test-images/christmas-tradition-gift-graphic-element-embellishment-red-green.png
#
# actual	response
# 0.0	0.05938561633229256
# 0.0	0.45843392610549927
# 0.0	2.0803692677873187e-05
# 0.0	1.1433589008902345e-07
# christmas	0.21969115734100342
# 0.0	0.01993425562977791
# 0.0	0.02466139756143093
# 0.0	0.003292621113359928
# 0.0	0.00016383343609049916
# 0.0	0.04192592576146126
# -------------------------------------
# image:  test-images/byb-tags-3-tag-5b-graphic-element-circle-stripes-peach-green-white.png
#
# actual	response
# 0.0	0.0008141250000335276
# 0.0	0.00023300985048990697
# 0.0	1.1659129995678086e-05
# 0.0	0.013724274933338165
# 0.0	6.674765984371334e-08
# 0.0	0.0015908434288576245
# 0.0	0.0834333524107933
# tag	0.3882063031196594
# 0.0	0.007551850285381079
# 0.0	1.3385299553192453e-06
# -------------------------------------
# image:  test-images/the-good-life-march-2020-elements-glitter-heart-2-graphic-love-element-cork-white-brown.png
#
# actual	response
# 0.0	0.00010547250712988898
# 0.0	2.2580237782676704e-05
# 0.0	0.008387771435081959
# heart	0.40284648537635803
# 0.0	5.745837938775367e-07
# 0.0	0.0030958682764321566
# 0.0	0.08555299788713455
# 0.0	0.007719483692198992
# 0.0	0.0006379203987307847
# 0.0	0.021257547661662102
# -------------------------------------
# image:  test-images/sent-template-video-game-valentine-stamp-graphic-element-computer-pixels-games-teen-boy-love-quotes.png
#
# actual	response
# 0.0	0.0014513700734823942
# 0.0	0.0017012374009937048
# 0.0	0.4026632308959961
# 0.0	0.0035114565398544073
# 0.0	0.2823045551776886
# template	0.9462990760803223
# 0.0	0.9251146912574768
# 0.0	0.04223421961069107
# 0.0	0.001961087342351675
# 0.0	0.04542084038257599
# -------------------------------------
# image:  test-images/slice-of-summer-leaf-doodle-3-graphic-doodles-drawings-illustrations-sketches-metal-element-green.png
#
# actual	response
# 0.0	0.001121949520893395
# leaf	0.004127502907067537
# 0.0	0.0013641513651236892
# 0.0	0.002196276793256402
# 0.0	0.050977565348148346
# 0.0	2.489889538992429e-06
# 0.0	1.2083299225196242e-05
# 0.0	0.001579677569679916
# 0.0	0.11958982050418854
# 0.0	0.3265070617198944
# -------------------------------------
# image:  test-images/textured-grunge-star-08-asset-shape-cutout-stamp-embellishment-texture-distressed-white-gray.png
#
# actual	response
# 0.0	0.9795093536376953
# 0.0	0.00486045191064477
# star	0.13602083921432495
# 0.0	2.701589210118982e-07
# 0.0	0.00017346919048577547
# 0.0	0.09785807877779007
# 0.0	0.0005529433256015182
# 0.0	0.00016199852689169347
# 0.0	0.00013510763528756797
# 0.0	1.3609246174439704e-08
# -------------------------------------
# image:  test-images/vintage-gifts-template-graphic-illustration-element-stamp-printable-christmas-black.png
#
# actual	response
# 0.0	3.060748895222787e-06
# 0.0	0.0012575339060276747
# 0.0	2.225097887276206e-05
# 0.0	1.9509971025399864e-05
# christmas	0.0038989665918052197
# template	0.9980186223983765
# 0.0	0.5461789965629578
# 0.0	0.02695574425160885
# vintage	0.003237880300730467
# illustration	0.9754362106323242
# -------------------------------------
# image:  test-images/back-to-basics-everyday-label-170-graphic-tab-tag-wordart-element-details-gold-brown.png
#
# actual	response
# 0.0	2.996629882545676e-05
# 0.0	2.2160024570894166e-07
# 0.0	0.23417924344539642
# 0.0	1.5253608580678701e-05
# 0.0	1.2999436194149894e-06
# 0.0	7.4723425314005e-06
# 0.0	0.0022551752626895905
# tag	0.9998464584350586
# 0.0	0.0027175869327038527
# 0.0	1.258875727216946e-05
# ---------------------------------------------------------------------------
# ModelError                                Traceback (most recent call last)
# <ipython-input-22-d94615b350b8> in <module>
#       9     with open(path, 'rb') as f:
#      10         payload = f.read()
# ---> 11     response = runtime.invoke_endpoint(EndpointName=endpoint, ContentType='application/x-image', Body=payload)
#      12     result = json.loads(response['Body'].read().decode())
#      13     print('-------------------------------------')
#
# ~/anaconda3/envs/mxnet_latest_p37/lib/python3.7/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     355                     "%s() only accepts keyword arguments." % py_operation_name)
#     356             # The "self" in this scope is referring to the BaseClient.
# --> 357             return self._make_api_call(operation_name, kwargs)
#     358
#     359         _api_call.__name__ = str(py_operation_name)
#
# ~/anaconda3/envs/mxnet_latest_p37/lib/python3.7/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     674             error_code = parsed_response.get("Error", {}).get("Code")
#     675             error_class = self.exceptions.from_code(error_code)
# --> 676             raise error_class(parsed_response, operation_name)
#     677         else:
#     678             return parsed_response
#
# ModelError: An error occurred (ModelError) when calling the InvokeEndpoint operation: Received client error (413) from model with message "<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 3.2 Final//EN">
# <title>413 Request Entity Too Large</title>
# <h1>Request Entity Too Large</h1>
# <p>The data value transmitted exceeds the capacity limit.</p>
# ". See https://eu-west-1.console.aws.amazon.com/cloudwatch/home?region=eu-west-1#logEventViewer:group=/aws/sagemaker/Endpoints/imageclassif-job-04-00-06-49-008-fa1272-2021-03-04-01-59-50-199 in account 466363126778 for more information.
